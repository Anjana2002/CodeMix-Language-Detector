# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjana2002/Language-Identification-for-Malayalam-English-Code-Mixed-Text/blob/main/data_preprocessing/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preprocessing of database

# %%
import re
import pandas as pd

# %%
df = pd.read_csv("malayalam_youtube_comments.csv")
df.head()
# Out:
#             id                                               text
# 0  63i4ZQcvpcQ  Download Duolingo for free: https://app.adjust...
# 1  63i4ZQcvpcQ                                          Ihjhuujuy
# 2  63i4ZQcvpcQ                                           അടിപൊളി😂
# 3  63i4ZQcvpcQ          Nayanthara kettiyathin shesham kanunnavar
# 4  63i4ZQcvpcQ                                               2050

# %%
#check row contain malayalam language
malayalam_pattern = r'[\u0D00-\u0D7F]+'
def remove_malayalam(text):
    if isinstance(text, str):
        return re.sub(malayalam_pattern, '', text)
    return text
df = df.applymap(remove_malayalam)
# Out:
# <ipython-input-20-fa83db749ddb>:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(remove_malayalam)

# %%
df.head()
# Out:
#             id                                               text
# 0  63i4ZQcvpcQ  Download Duolingo for free: https://app.adjust...
# 1  63i4ZQcvpcQ                                          Ihjhuujuy
# 2  63i4ZQcvpcQ                                                  😂
# 3  63i4ZQcvpcQ          Nayanthara kettiyathin shesham kanunnavar
# 4  63i4ZQcvpcQ                                               2050

# %%
def remove_emoji(text):
    if isinstance(text, str):
        emoji_pattern = re.compile(
            "["
            u"\U0001F600-\U0001F64F"  # Emoticons
            u"\U0001F300-\U0001F5FF"  # Symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # Transport & map symbols
            u"\U0001F700-\U0001F77F"  # Alchemical symbols
            u"\U0001F780-\U0001F7FF"  # Geometric shapes extended
            u"\U0001F800-\U0001F8FF"  # Supplemental arrows-C
            u"\U0001F900-\U0001F9FF"  # Supplemental symbols and pictographs
            u"\U0001FA00-\U0001FA6F"  # Chess symbols
            u"\U0001FA70-\U0001FAFF"  # Symbols and pictographs extended-A
            u"\U00002702-\U000027B0"  # Dingbats
            u"\U000024C2-\U0001F251"  # Enclosed characters
            u"\U0001F1E0-\U0001F1FF"  # Flags (iOS)
            "]+", flags=re.UNICODE)

        text = emoji_pattern.sub(r'', text)
        return text.strip() if text.strip() else None  # Return None if text is empty after removing emojis
    return text
df = df.applymap(remove_emoji)
# Out:
# <ipython-input-22-8c2ba3ba2be6>:22: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(remove_emoji)

# %%
def remove_numbers(text):
    if isinstance(text, str):
        text = re.sub(r'[!@#$%^&*()_\-+=\[\]{}|\\;:"\'<>,./?`~]', '', text)
        text = re.sub(r'\d+', '', text)
        text = text.strip()
        return text if text else None
    return text
df = df.applymap(remove_numbers)
# Out:
# <ipython-input-23-f7cf390aaef4>:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(remove_numbers)

# %%
def remove_non_visible(text):
    if isinstance(text, str):
        # This removes zero-width spaces and other invisible characters
        return re.sub(r'[^\x20-\x7E]+', '', text).strip() or None
    return text
df = df.applymap(remove_non_visible)
# Out:
# <ipython-input-24-9bbbc98b68c4>:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(remove_non_visible)

# %%
df = df.applymap(lambda x: ' '.join(str(x).split()) if isinstance(x, str) else x)
df = df.replace(r'^\s*$', None, regex=True)

df = df.dropna(how='any')
# df.dropna(inplace=True)
df.to_csv('filtered_file.csv', index=False)
# Out:
# <ipython-input-25-7672086e80fb>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ' '.join(str(x).split()) if isinstance(x, str) else x)

# %%
print(df.isnull().sum())
print(df.info())
# Out:
# id      0
# text    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 58576 entries, 0 to 75291
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      58576 non-null  object
#  1   text    58576 non-null  object
# dtypes: object(2)
# memory usage: 1.3+ MB
# None
