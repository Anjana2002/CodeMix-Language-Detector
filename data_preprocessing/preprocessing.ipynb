# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjana2002/Language-Identification-for-Malayalam-English-Code-Mixed-Text/blob/main/data_preprocessing/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preprocessing of database

# %%
# !pip install contractions

# %%
import re
import pandas as pd
import contractions

# %%
df = pd.read_csv("malayalam_youtube_comments.csv")
df.head()
# Out:
#       video_id                                               text
# 0  63i4ZQcvpcQ  Download Duolingo for free: https://app.adjust...
# 1  63i4ZQcvpcQ                                          Ihjhuujuy
# 2  63i4ZQcvpcQ                                           അടിപൊളി😂
# 3  63i4ZQcvpcQ          Nayanthara kettiyathin shesham kanunnavar
# 4  63i4ZQcvpcQ                                               2050

# %%
#check row contain malayalam language
malayalam_pattern = r'[\u0D00-\u0D7F]+'
def remove_malayalam(text):
    if isinstance(text, str):
        return re.sub(malayalam_pattern, '', text)
    return text
df = df.applymap(remove_malayalam)
# Out:
# <ipython-input-15-fa83db749ddb>:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(remove_malayalam)

# %%
df.head()
# Out:
#       video_id                                               text
# 0  63i4ZQcvpcQ  Download Duolingo for free: https://app.adjust...
# 1  63i4ZQcvpcQ                                          Ihjhuujuy
# 2  63i4ZQcvpcQ                                                  😂
# 3  63i4ZQcvpcQ          Nayanthara kettiyathin shesham kanunnavar
# 4  63i4ZQcvpcQ                                               2050

# %%
df = df.applymap(lambda x: ' '.join(str(x).split()) if isinstance(x, str) else x)
df = df.replace(r'^\s*$', None, regex=True)
df = df.dropna(how='any')
# Out:
# <ipython-input-17-5b979a95dc2b>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ' '.join(str(x).split()) if isinstance(x, str) else x)

# %%
print(df.isnull().sum())
print(df.info())
# Out:
# video_id    0
# text        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 73182 entries, 0 to 75168
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   video_id  73182 non-null  object
#  1   text      73182 non-null  object
# dtypes: object(2)
# memory usage: 1.7+ MB
# None

# %%
df = df[df['text'].apply(lambda x: len(x.split()) >= 2 if isinstance(x, str) else False)]

# %%
def trim_repeated(word):
  return re.sub(r'(.)\1{2,}',r'\1\1', word)
df['text'] = df['text'].apply(trim_repeated)

# %%
def expand_contractions(text):
    if isinstance(text, str):
        return contractions.fix(text)
    return text
df['text'] = df['text'].apply(expand_contractions)

# %%
df.to_csv('malayalam_youtube_comments_filtered.csv', index=False)
